# %% [markdown]
# <a href="https://colab.research.google.com/github/MADHUPRIYAAA/HCI-PROJECT/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="en">

<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Event management</title>
  <link rel="stylesheet" href="pstyle.css">
</head>

<body>
  <!-- Navigation Bar -->
  <header>
    <nav>
      <ul class="nav-links">
        <li><button onclick="navigateTo('home')">Home</button></li>
        <li><button onclick="navigateTo('menu')">Menu</button></li>
        <li><button onclick="navigateTo('about')">About</button></li>
        <li><button onclick="navigateTo('contact')">Contact</button></li>
      </ul>

      <div class="auth-buttons">
        <!-- Logo and Name -->
        <div class="logo-container">
          <img
            src="https://plus.unsplash.com/premium_photo-1668051040456-24c63abd95b4?w=500&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8NXx8ZXZlbnQlMjBtYW5hZ21lbnQlMjBsb2dvfGVufDB8fDB8fHww"
            alt="Logo" class="logo-image">
          <span class="site-name">Event Invitation</span> <!-- Replace with your site's name -->
        </div>
      </div>
    </nav>
  </header>

  <!-- Sections -->
  <main>
    <section id="home" class="section">
      <h1>Welcome to Event Invitations</h1>
      <button class="cta-button" onclick="getStarted()">Get Started</button>
    </section>


    <section id="menu" class="section" style="display: none;">
      <h2>Latest Events Posts</h2>
      <div class="menu-container">


        <!-- Event 1: Wedding Invitation -->
        <div class="menu-post">
          <img
            src="https://png.pngtree.com/element_our/sm/20171115/sm_5a0c20911978e.jpg"
            alt="Wedding Image">
          <h3>[Bride's Name] & [Groom's Name] Wedding</h3>
          <div class="post-info">
            <span>Wedding Date: June 25, 2024</span>
            <span>Venue: Sunset Beach Resort</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('weddingDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 2: Birthday Party -->
        <div class="menu-post">
          <img
            src="https://png.pngtree.com/png-vector/20200425/ourmid/pngtree-black-and-gold-birthday-invitation-png-image_2070604.jpg"
            alt="Birthday Party Image">
          <h3>Join Us for Alex's Birthday Bash</h3>
          <div class="post-info">
            <span>Date: July 5, 2024</span>
            <span>Venue: Bluebell Gardens</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('birthdayDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 3: Corporate Meeting -->
        <div class="menu-post">
          <img
            src="https://plus.unsplash.com/premium_photo-1661492172846-06f14551c039?w=400&auto=format&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Corporate Meeting Image">
          <h3>Annual Corporate Meeting</h3>
          <div class="post-info">
            <span>Date: July 15, 2024</span>
            <span>Venue: Downtown Conference Hall</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('corporateDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 4: Baby Shower -->
        <div class="menu-post">
          <img
            src="https://plus.unsplash.com/premium_photo-1664392409097-7e49051811cb?w=400&auto=format&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Baby Shower Image">
          <h3>Baby Shower Celebration</h3>
          <div class="post-info">
            <span>Date: August 10, 2024</span>
            <span>Venue: Harmony Hall</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('babyShowerDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 5: Graduation Party -->
        <div class="menu-post">
          <img src="https://images.unsplash.com/photo-1558642452-9d2a7deb7f62?w=500&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Graduation Party Image">
          <h3>Graduation Celebration for John</h3>
          <div class="post-info">
            <span>Date: August 20, 2024</span>
            <span>Venue: Grand Ivy Hall</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('graduationDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 6: Music Festival -->
        <div class="menu-post">
          <img src="https://images.unsplash.com/photo-1511671782779-c97d3d27a1d4?w=500&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Music Festival Image">
          <h3>Summer Beats Music Festival</h3>
          <div class="post-info">
            <span>Date: September 1, 2024</span>
            <span>Venue: Open Grounds Arena</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('musicFestivalDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 7: Charity Gala -->
        <div class="menu-post">
          <img src="https://images.unsplash.com/photo-1523050854058-8df90110c9f1?w=500&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Charity Gala Image">
          <h3>Annual Charity Gala</h3>
          <div class="post-info">
            <span>Date: September 20, 2024</span>
            <span>Venue: Crystal Ballroom</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('charityGalaDetails')">Read Now</a>
          </div>
        </div>

        <!-- Event 8: Art Exhibition -->
        <div class="menu-post">
          <img src="https://images.unsplash.com/photo-1494526585095-c41746248156?w=500&fit=crop&q=60&ixlib=rb-4.0.3"
            alt="Art Exhibition Image">
          <h3>Art Exhibition: Creativity Unleashed</h3>
          <div class="post-info">
            <span>Date: October 5, 2024</span>
            <span>Venue: City Art Gallery</span>
          </div>
          <div class="read-more">
            <a onclick="showDetails('artExhibitionDetails')">Read Now</a>
          </div>
        </div>

        <div id="weddingDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img src="https://png.pngtree.com/element_our/sm/20171115/sm_5a0c20911978e.jpg"
              alt="Wedding Image">
            <h2>Wedding Invitation Details</h2>
            <p><strong>Couple:</strong> [Bride's Name] & [Groom's Name]</p>
            <p><strong>Date:</strong> June 25, 2024</p>
            <p><strong>Venue:</strong> Sunset Beach Resort</p>
            <button onclick="hideDetails('weddingDetails')">Close</button>
          </div>
        </div>

        <div id="birthdayDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img
              src="https://png.pngtree.com/png-vector/20200425/ourmid/pngtree-black-and-gold-birthday-invitation-png-image_2070604.jpg"
              alt="Birthday Party Image">
            <h2>Birthday Party Details</h2>
            <p><strong>Celebrant:</strong> Alex</p>
            <p><strong>Date:</strong> July 5, 2024</p>
            <p><strong>Venue:</strong> Bluebell Gardens</p>
            <button onclick="hideDetails('birthdayDetails')">Close</button>
          </div>
        </div>
        <!-- Event 3: Corporate Meeting -->
        <div id="corporateDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img
              src="https://plus.unsplash.com/premium_photo-1661492172846-06f14551c039?w=400&auto=format&fit=crop&q=60&ixlib=rb-4.0.3"
              alt="Corporate Meeting Image">
            <h2>Corporate Meeting Details</h2>
            <p><strong>Event:</strong> Annual Corporate Meeting</p>
            <p><strong>Date:</strong> July 15, 2024</p>
            <p><strong>Venue:</strong> Downtown Conference Hall</p>
            <button onclick="hideDetails('corporateDetails')">Close</button>
          </div>
        </div>

        <!-- Event 4: Baby Shower -->
        <div id="babyShowerDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img
              src="https://plus.unsplash.com/premium_photo-1664392409097-7e49051811cb?w=400&auto=format&fit=crop&q=60&ixlib=rb-4.0.3"
              alt="Baby Shower Image">
            <h2>Baby Shower Celebration Details</h2>
            <p><strong>Event:</strong> Baby Shower Celebration</p>
            <p><strong>Date:</strong> August 10, 2024</p>
            <p><strong>Venue:</strong> Harmony Hall</p>
            <button onclick="hideDetails('babyShowerDetails')">Close</button>
          </div>
        </div>

        <!-- Event 5: Graduation Party -->
        <div id="graduationDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img src="https://images.unsplash.com/photo-1558642452-9d2a7deb7f62?w=800&fit=crop&q=60"
              alt="Graduation Party Image">
            <h2>Graduation Party Details</h2>
            <p><strong>Celebration:</strong> John's Graduation Party</p>
            <p><strong>Date:</strong> August 20, 2024</p>
            <p><strong>Venue:</strong> Grand Ivy Hall</p>
            <button onclick="hideDetails('graduationDetails')">Close</button>
          </div>
        </div>

        <!-- Event 6: Music Festival -->
        <div id="musicFestivalDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img src="https://images.unsplash.com/photo-1511671782779-c97d3d27a1d4?w=800&fit=crop&q=60"
              alt="Music Festival Image">
            <h2>Music Festival Details</h2>
            <p><strong>Event:</strong> Summer Beats Music Festival</p>
            <p><strong>Date:</strong> September 1, 2024</p>
            <p><strong>Venue:</strong> Open Grounds Arena</p>
            <button onclick="hideDetails('musicFestivalDetails')">Close</button>
          </div>
        </div>

        <!-- Event 7: Charity Gala -->
        <div id="charityGalaDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img src="https://images.unsplash.com/photo-1523050854058-8df90110c9f1?w=800&fit=crop&q=60"
              alt="Charity Gala Image">
            <h2>Charity Gala Details</h2>
            <p><strong>Event:</strong> Annual Charity Gala</p>
            <p><strong>Date:</strong> September 20, 2024</p>
            <p><strong>Venue:</strong> Crystal Ballroom</p>
            <button onclick="hideDetails('charityGalaDetails')">Close</button>
          </div>
        </div>

        <!-- Event 8: Art Exhibition -->
        <div id="artExhibitionDetails" class="overlay" style="display: none;">
          <div class="details-container">
            <img src="https://images.unsplash.com/photo-1494526585095-c41746248156?w=800&fit=crop&q=60"
              alt="Art Exhibition Image">
            <h2>Art Exhibition Details</h2>
            <p><strong>Event:</strong> Creativity Unleashed Art Exhibition</p>
            <p><strong>Date:</strong> October 5, 2024</p>
            <p><strong>Venue:</strong> City Art Gallery</p>
            <button onclick="hideDetails('artExhibitionDetails')">Close</button>
          </div>
        </div>
      </div>
    </section>

    <section id="about" class="section" style="display: none;">
      <h2>About Us</h2>
      <p>We are dedicated to making your events a success. From corporate
        gatherings to personal celebrations, we handle every detail with precision and care. Learn more about our
        services.</p>
      <button type="button">Learn More</button>
    </section>

    <section id="contact" class="section" style="display: none;">
      <h2>Contact Us</h2>
      <form>
        <label for="contact-name">Name:</label>
        <input type="text" id="contact-name" required>

        <label for="contact-email">Email:</label>
        <input type="email" id="contact-email" required>

        <label for="contact-message">Message:</label>
        <textarea id="contact-message" required></textarea>

        <button type="submit">Send Message</button>
      </form>
    </section>
  </main>
  <footer>
    <p>&copy; 2024 My Creative Events. All rights reserved.</p>
  </footer>
  <script src="pscript.js"></script>
</body>

</html>
