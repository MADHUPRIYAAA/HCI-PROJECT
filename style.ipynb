# %% [markdown]
# <a href="https://colab.research.google.com/github/MADHUPRIYAAA/HCI-PROJECT/blob/main/style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/* General Styles */
body {
  font-family: 'Arial', sans-serif;
  margin: 0;
  padding: 0;
  background: #4dc0ba;
  color: #333;
}

header {
  background: linear-gradient(to right, #5fffff, #7bfafe);
  /* Gradient background */
  color: rgb(80, 167, 162);
  padding: 20px 10px;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
}

nav {
  display: flex;
  justify-content: space-between;
  align-items: center;
}

.nav-links {
  list-style-type: none;
  margin: 0;
  padding: 0;
}

.nav-links li {
  display: inline;
  margin-right: 25px;
}

.nav-links button {
  background-color: #ffffff;
  color: #333;
  border: none;
  padding: 12px 20px;
  cursor: pointer;
  font-size: 16px;
  border-radius: 5px;
  transition: all 0.3s ease;
}

.nav-links button:hover {
  background-color: #7beffe;
  color: #fff;
  transform: scale(1.05);
}

.auth-buttons button {
  background-color: #333;
  color: white;
  border: none;
  padding: 10px 20px;
  margin-left: 20px;
  cursor: pointer;
  font-size: 16px;
  border-radius: 5px;
  transition: all 0.3s ease;
}

.auth-buttons button:hover {
  background-color: #5ffff7;
  color: white;
  transform: scale(1.05);
}

.auth-buttons button:active {
  transform: scale(0.98);
}

main {
  padding: 40px 15px;
}

.section {
  display: none;
  padding: 40px;
  margin-top: 20px;
  background-color: #fff;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
  border-radius: 8px;
  transition: all 0.3s ease;
}

/* Additional Mobile Responsiveness */
@media (max-width: 768px) {
  .nav-links {
    display: flex;
    flex-direction: column;
    align-items: center;
  }

  .nav-links li {
    margin-right: 0;
    margin-bottom: 15px;
  }

  .auth-buttons {
    display: flex;
    flex-direction: column;
  }

  .auth-buttons button {
    margin-left: 0;
    margin-bottom: 10px;
  }

  #home h1 {
    font-size: 28px;
  }

  #home p {
    font-size: 16px;
  }
}

/* Home Section Styles */
#home {
  display: block;
  padding: 100px 20px;
  background-image: url('https://images.unsplash.com/photo-1670028514318-0ac718c0590d?w=500&auto=format&fit=crop&q=60&ixlib=rb-4.0.3');
  /* Replace with your image URL */
  background-size: cover;
  /* Ensures the image covers the entire section */
  background-position: center;
  /* Centers the image */
  background-repeat: no-repeat;
  /* Prevents image from repeating */
  color: white;
  text-align: center;
  border-radius: 10px;
  box-shadow: 50px 50px 50px rgba(0, 0, 0, 0.1);
  position: relative;
  overflow: hidden;
}

#home h1 {
  font-size: 50px;
  color: #fff;
  font-family: 'Arial', sans-serif;
  text-shadow: 3px 3px 5px rgba(0, 0, 0, 0.3);
  margin-bottom: 20px;
  transition: all 0.3s ease-in-out;
}

#home h1:hover {
  transform: scale(1.05);
}

#home p:hover {
  color: #ffeb3b;
  transform: translateY(5px);
}

#home .cta-button {
  padding: 15px 30px;
  background-color: #ffeb3b;
  color: #333;
  font-size: 20px;
  font-weight: bold;
  border-radius: 25px;
  margin-top: 30px;
  cursor: pointer;
  transition: all 0.3s ease;
  border: none;
  text-transform: uppercase;
}

#home .cta-button:hover {
  background-color: #5df5e8;
  color: white;
  transform: scale(1.05);
}



/* munu Section Styles */
#menu {
  padding: 40px;
  background-color: #fff;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
  margin-top: 20px;
  border-radius: 8px;
}

#menu h2 {
  color: #5df5e8;
  font-size: 36px;
  text-align: center;
  margin-bottom: 40px;
}

.menu-post {
  background: #d4f1f7;
  padding: 20px;
  margin-bottom: 30px;
  border-radius: 8px;
  box-shadow: 0 2px 6px rgba(0, 0, 0, 0.1);
  transition: all 0.3s ease;
  display: flex;
  flex-direction: column;
  justify-content: space-between;
}

.menu-post:hover {
  transform: translateY(-5px);
  box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
}

.menu-post img {
  width: 100%;
  height: 200px;
  object-fit: cover;
  border-radius: 8px;
  margin-bottom: 20px;
}

.menu-post h3 {
  font-size: 24px;
  color: #333;
  margin-bottom: 15px;
}

.menu-post p {
  font-size: 16px;
  color: #666;
  line-height: 1.6;
  margin-bottom: 20px;
}

.menu-post .post-info {
  display: flex;
  justify-content: space-between;
  align-items: center;
  color: #888;
  font-size: 14px;
}

.menu-post .post-info span {
  margin-right: 10px;
}

.menu-post .read-more {
  text-align: center;
  margin-top: 20px;
}

.menu-post .read-more a {
  font-size: 16px;
  color: #030f0e;
  text-decoration: none;
  font-weight: bold;
  border: 1px solid #5df5e8;
  padding: 10px 20px;
  border-radius: 5px;
  transition: background-color 0.3s ease, color 0.3s ease;
}

.menu-post .read-more a:hover {
  background-color: #5df5e8;
  color: white;
}

/* Cards Layout - Responsive */
.menu-container {
  display: grid;
  grid-template-columns: repeat(auto-fill, minmax(280px, 1fr));
  gap: 20px;
}

/* Additional Styling for Mobile */
@media (max-width: 768px) {
  #menu h2 {
    font-size: 30px;
  }

  .menu-post {
    padding: 15px;
  }

  .menu-post h3 {
    font-size: 20px;
  }

  .menu-post p {
    font-size: 14px;
  }

  .menu-post .post-info {
    font-size: 12px;
  }

  .menu-post .read-more a {
    font-size: 14px;
  }
}

/* About Section Styles */
#about {
  background-color: #fff;
  border-radius: 8px;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
  padding: 50px 20px;
  margin: 50px auto;
  max-width: 800px;
  transform: translateY(20px);
  opacity: 0;
  animation: fadeIn 1s forwards;
  background: linear-gradient(135deg, #e0f7fa 0%, #ffffff 100%);
}

#about h2 {
  font-size: 32px;
  color: #00695c;
  text-align: center;
  margin-bottom: 20px;
  font-family: 'Arial', sans-serif;
}

#about p {
  font-size: 18px;
  color: #333;
  line-height: 1.6;
  text-align: center;
  margin-bottom: 30px;
}

#about button {
  padding: 12px 20px;
  background-color: #5df5e8;
  color: white;
  border: none;
  cursor: pointer;
  font-size: 18px;
  border-radius: 5px;
  transition: all 0.3s ease;
  margin-top: 20px;
  display: block;
  width: 100%;
  text-align: center;
  font-weight: bold;
}

#about button:hover {
  background-color: #5df5e8;
}

#about button:active {
  transform: scale(0.98);
}

/* Animations */
@keyframes fadeIn {
  0% {
    opacity: 0;
    transform: translateY(20px);
  }

  100% {
    opacity: 1;
    transform: translateY(0);
  }
}


#contact {
  background-color: #fff;
  border-radius: 8px;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
}

/* Contact Form Styles */
#contact {
  padding: 40px 20px;
  background-color: #f9f9f9;
  box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
  border-radius: 10px;
  max-width: 600px;
  margin: 50px auto;
}

#contact h2 {
  font-size: 28px;
  color: #333;
  text-align: center;
  margin-bottom: 20px;
  font-family: 'Arial', sans-serif;
}

#contact form {
  display: flex;
  flex-direction: column;
}

#contact label {
  margin-bottom: 8px;
  font-size: 16px;
  color: #555;
}

#contact input,
#contact textarea {
  padding: 12px;
  margin-bottom: 15px;
  border: 1px solid #ccc;
  border-radius: 5px;
  font-size: 16px;
  transition: border-color 0.3s ease;
}

#contact input:focus,
#contact textarea:focus {
  border-color: #5df5e8;
  outline: none;
}

#contact button {
  padding: 12px 20px;
  background-color: #5df5e8;
  color: white;
  border: none;
  cursor: pointer;
  font-size: 18px;
  border-radius: 5px;
  transition: all 0.3s ease;
  margin-top: 15px;
  align-self: center;
}

#contact button:hover {
  background-color: #5df5e8;
}

#contact button:active {
  transform: scale(0.98);
}

/* Footer Styles */
footer {
  background-color: #333;
  color: white;
  text-align: center;
  padding: 20px;
  margin-top: 30px;
  box-shadow: 0 -4px 10px rgba(0, 0, 0, 0.1);
  font-family: 'Arial', sans-serif;
}

footer p {
  margin: 0;
  font-size: 14px;
}

/* Modal Styles */
.auth-buttons {
  display: flex;
  align-items: center;
}

/* Style for the logo */
.logo-container {
  display: flex;
  align-items: center;
  justify-content: center;
}

.logo-image {
  width: 60px;
  /* Adjust the size */
  height: 60px;
  /* Keep the height the same */
  border-radius: 50%;
  /* Makes the logo circular */
  object-fit: cover;
  /* Prevents the image from stretching */
  border: 3px solid #3498db;
  /* Optional: Adds a blue border around the logo */
  box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
  /* Optional: Adds a shadow */
}

.site-name {
  font-size: 24px;
  margin-left: 10px;
  /* Adds space between the logo and the site name */
  color: #333;
  font-weight: bold;
}

/* Blurred Background */
.overlay {
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  background-color: rgba(0, 0, 0, 0.5);
  /* Semi-transparent dark background */
  backdrop-filter: blur(8px);
  /* Blur effect */
  display: flex;
  justify-content: center;
  align-items: center;
  z-index: 1000;
}

/* Details Container */
.details-container {
  background: #fff;
  border-radius: 10px;
  padding: 20px;
  text-align: center;
  box-shadow: 0 5px 15px rgba(0, 0, 0, 0.3);
  width: 80%;
  max-width: 500px;
}

.details-container img {
  max-width: 100%;
  border-radius: 8px;
  margin-bottom: 20px;
}

.details-container button {
  background-color: #007BFF;
  color: #fff;
  padding: 10px 20px;
  border: none;
  border-radius: 5px;
  cursor: pointer;
}

.details-container button:hover {
  background-color: #0056b3;
}
